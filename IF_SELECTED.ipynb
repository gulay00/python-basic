# %%
a =["Gulay","Lale","Asif"]
name="Leyla"
if name in a:
        print(name,"istirakcidir.")
else:
        print(name,"istirakci deyil")

# %%
eded = str(input("Ededi daxil edin:"))
if eded == eded[::-1]:
    print(eded,"polindromdur")
else:
    print(eded,"polindrom deyil")

# %%
eded = str(input("Ededi daxil edin:"))
ters = ""  

for x in eded:
    ters = x + ters  

if eded == ters:
    print(eded, "polindromdur")
else:
    print(eded, "polindrom deyil")

# %%
a = int(input("1-ci Ededi daxil edin:"))
b = int(input("2-ci Ededi daxil edin:"))
c = int(input("3-cu Ededi daxil edin:"))
if a + b > c and a + c > b and b + c > a:
    print("Ucbucaqdir")
else:
    print("Ucbucaq deyil")

# %%
a = int(input("1-ci Ededi daxil edin:"))
b = int(input("2-ci Ededi daxil edin:"))
operator = str(input("Operatoru daxil edin:"))
if operator == "+":
    print("Cem:" , a + b)
elif operator == "-":
    print("Ferq:" , a - b)
elif operator == "*":
    print("Hasil:" , a * b)
elif operator == "/":
    print("Bolme:" , a / b)
else:
    print("Operatoru duzgun daxil edin")

# %%
telebe_bali =int(input("Bali daxil edin:"))
if telebe_bali>90:
    print("A")
elif telebe_bali>80:
    print("B")
elif telebe_bali>70:
    print("C")
else:
    print("Kesildiniz")

# %%
list1="Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since"
set1=set(list1)
dict={}
for i in set1:
    if i in list1:
        dict[i]=list1.count(i)

print(dict)

# %%
#Task7
sentence = "Java and JavaScript are not the same"
a_count=0
for x in sentence:
    if x == "a":
      a_count+=1

print(a_count)

# %%
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1

# %%
#Task2
n = int(input("Ededi daxil edin:"))
if n >= 1 and n <= 100:
  if n % 2!= 0:
    print("Weird")
  elif (n>2 and n<5) or n>20:
    print("Not Weird")  
  elif n>6 and n <20 :
     print("Weird")
else:
    print("1-le 100 arasinda eded daxil edin!")

# %%
a = int(input("1-ci Ededi daxil edin:"))
b = int(input("2-ci Ededi daxil edin:"))
operator = str(input("Operatoru daxil edin:"))
value=0
if operator == "+":
   value=a+b
elif operator == "-":
   value=a-b
elif operator == "*":
   value=a*b
elif operator == "/":
   value=a/b 
else:
    print("Operatoru duzgun daxil edin")

print(f"{a}{operator}{b}={value}")

# %%
n = int(input("Faktorial ededini daxil edin:"))
fakt = 0
m=1
while fakt <= n:
  fakt *= m
  m+=1
  if fakt == n:
      print(m)

# %%
l= [5,5,6,88,88,88,9]
n2=[]
def again(l):
    for x in l:
        if l.count(x) > 1:
             n2.append(x)
    return set(n2)
            
print(again(l))

# %%
#Task7
sentence = "Java and JavaScript are not the same"
a_count=0
for x in sentence:
    if x == "a":
      a_count+=1

print(a_count)

# %%
#Loops TAsk1
numbers = [3, -2, 8, 0, 5, -7, 10, 11]
numbers2=[]
for x in numbers:
    if x > 0 and x % 2 == 0:
        numbers2.append(x)

print(numbers2)

# %%
#Task6
nums = [10, 20, 30, 40, 50]
orta=sum(nums)/len(nums)
for x in nums:
    if x > orta:
        print(x)

# %%
#TAsk8
numbers = [3, 5, 6, 8, 11, 14, 17, 18]
cem = 0
for x in numbers:
    if x % 2 == 0:
        cem+=x

print(cem)

# %%
#Task10
nums = [-3, 4, 0, 7, -2, 10]
print([x**2 for x in nums if x>0])

# %%
#Task11
fruits = ["apple", "banana", "cherry", "date", "fig"]
print([fruits[x] for x in range(len(fruits)) if x %2==0])

# %%
#TAsk16
a = [1, 3, 5, 7, 9]
b = [2, 3, 6, 7, 10, 9]
print([x for x in a if x in b])

# %%
#Task17
nums = [10, 20, 30, 40, 50, 60]
nums2 = []
for x in range(len(nums)):
    if x %2 == 0:
        nums2.append(nums[x]*3)
    else:
        nums2.append(int(nums[x]/2))

print(nums2)

# %%
#Task19
nums = [5, 8, 12, 15, 18, 21, 24]
print([x for x in nums if x%3==0 and x%4==0 ])

# %%
n=1
while n<20:
    if n%2==0:
        print(n)
   
    n+=1

# %%
l=[]
while x:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print(sum(l))

# %%
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1
else:
    print("Sade ededdir")

# %%
#4
l=[]
while True:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print("Cem:",sum(l))
       break

# %%
n = int(input("Faktorial ededini daxil edin:"))
fakt = 1
m=1
while fakt <= n:
  fakt *= m
  if fakt == n:
      print(m)
      break
  m+=1

# %%
a =["Gulay","Lale","Asif"]
name="Leyla"
if name in a:
        print(name,"istirakcidir.")
else:
        print(name,"istirakci deyil")

# %%
eded = str(input("Ededi daxil edin:"))
if eded == eded[::-1]:
    print(eded,"polindromdur")
else:
    print(eded,"polindrom deyil")

# %%
eded = str(input("Ededi daxil edin:"))
ters = ""  

for x in eded:
    ters = x + ters  

if eded == ters:
    print(eded, "polindromdur")
else:
    print(eded, "polindrom deyil")

# %%
a = int(input("1-ci Ededi daxil edin:"))
b = int(input("2-ci Ededi daxil edin:"))
c = int(input("3-cu Ededi daxil edin:"))
if a + b > c and a + c > b and b + c > a:
    print("Ucbucaqdir")
else:
    print("Ucbucaq deyil")

# %%
a = int(input("1-ci Ededi daxil edin:"))
b = int(input("2-ci Ededi daxil edin:"))
operator = str(input("Operatoru daxil edin:"))
if operator == "+":
    print("Cem:" , a + b)
elif operator == "-":
    print("Ferq:" , a - b)
elif operator == "*":
    print("Hasil:" , a * b)
elif operator == "/":
    print("Bolme:" , a / b)
else:
    print("Operatoru duzgun daxil edin")

# %%
telebe_bali =int(input("Bali daxil edin:"))
if telebe_bali>90:
    print("A")
elif telebe_bali>80:
    print("B")
elif telebe_bali>70:
    print("C")
else:
    print("Kesildiniz")

# %%
list1="Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since"
set1=set(list1)
dict={}
for i in set1:
    if i in list1:
        dict[i]=list1.count(i)

print(dict)

# %%
prices = {
    "box_of_spaghetti" : 4,
    "lasagna"  : 5,
    "hamburger" : 2
   }
quantity = {
    "box_of_spaghetti" : 6,
    "lasagna"  : 10,
    "hamburger" : 0
    }

money_spent = 0
for i in prices:
    if prices[i] >= 5:
     money_spent = money_spent + (prices[i] * quantity[i])
    
    
print(money_spent)

# %%
derece = int(input("Dereceni  daxil edin:"))
vahid = input("Vahid Celcius-C yoxsa Fahrenheit_F?")
if vahid=="C":
    print(round((derece*1.8)+32),"F")
elif vahid=="F":
    print(round((derece-32)*5/9),"C")
else:
    print("Vahidi duzgun daxil edin.")

# %%
ad="Gulay"
kod=1234
username=str(input("Adinizi daxil edin:"))
password=int(input("Kodunuzu daxil edin:"))
cehd=0
while cehd < 3:
    username = input("Adinizi daxil edin: ")
    password = int(input("Kodunuzu daxil edin: "))
    
 if username=="Gulay" and password==1234:
    print("Welcome")
    break
 else:
    cehd+=1
 if cehd>= 3:
    print("Account blocked")

# %%
nums = [12, 4, 9, 20, 4, 9, 100, 2]
en_b=max(nums)
print(en_b)
en_k=min(nums)
print(en_k)
orta=sum(nums)/len(nums)
print(orta)
m_num=int(len(nums)/2)
median=[]
if m_num%2==1:
   median.append(nums[m_num]) 
else:
    median.append(nums[m_num-1])
    median.append(nums[m_num])

print(median)
for x in nums:
   if  nums.count(x)!=1:
    print(x)

# %%
bal=int(input("Balinizi daxil edin:"))
n=" "
if bal>=0 and bal<=100:
    if bal >=90:
        n="A"
    elif bal>=80:
        n="B"
    elif bal>=70:
        n="C"
    elif bal>=60:
        n="D"
    elif bal<60 :
        n="F"
    print("Neticeniz:",n)
else:
        print("Bali duzgun daxil edin!")

# %%
a = int(input("1-ci ededi daxil edin:"))
b = int(input("2-ci ededi daxil edin:"))
c=a+b
if c%2==0 and c%3==0:
    print("OK")
else:
    print("NO")
