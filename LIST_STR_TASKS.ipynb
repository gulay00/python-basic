# %%
a = [1,3,5,6,7,8]
a.sort()
print("Ikinci en boyuk eded:",a[-2])

# %%
dict = {"name":"Gulay","last":"Muradli"}
print("Keys:",list(dict.keys()))
print("Values:",list(dict.values()))

# %%
#Soft Task1
numbers = [3, 5, 7, 2, 8]
print("Cem:",sum(numbers))

# %%
#Task2
fruits = ["alma", "armud", "banan"]
for x in fruits:
    print(x)

# %%
#Task3
colors = ["qırmızı", "yaşıl", "mavi", "sarı"]
print(len(colors))

# %%
#Task4
numbers = [12, 7, 22, 3, 15]
print(max(numbers))

# %%
#Task5
numbers = [10, 20, 30, 40]
print("Cem:",sum(numbers))
print("Ededi orta:",sum(numbers)/len(numbers))

# %%
#Task6
people = [("Ali", 25), ("Veli", 30), ("Aysel", 22)]
names = []
ages = []

for x in people:
    names.append(x[0])  
    ages.append(x[1])   

print(names)
print(ages)

# %%
#Task7
numbers = [1, 2, 3, 4, 5]
numbers.reverse()
print(numbers)

# %%
numbers2=list(reversed(numbers))
print(numbers2)

# %%
#Task8
words = ["alma", "armud", "banan"]
for x in words:
    print(x,len(x))

# %%
#Task9
numbers = [2, 3, 4]
squared=[]
for x in numbers:
    i = x**2
    squared.append(i)

print(squared)

# %%
#Task 10
numbers = [15, 3, 20, 7, 10]
numbers2 = sorted(numbers,reverse=False)
print("Max:",numbers2[-1])
print("Min:",numbers2[0])

# %%
#Lists1
numbers = [2, 4, 6, 8]
numbers.append(10)
print(len(numbers))

# %%
#Task2
fruits = ["apple", "banana", "cherry", "kiwi"]
print(fruits.pop())
print(fruits)

# %%
#Task3
colors = ["red", "blue", "green", "yellow"]
colors.append("purple")

print("Siralanmis:",sorted(colors,reverse=False))
print("Tersine:",sorted(colors,reverse=True))

# %%
#Task4
fruits = ["apple", "banana", "cherry"]
fruits.pop(1)
print(fruits)

# %%
fruits = ["apple", "banana", "cherry"]
del fruits[1]
print(fruits)

# %%
#Task5
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list1.extend(list2)
print(list1)

# %%
#Task6
text = "Python is fun"
print(text.upper())
print(text.lower())

# %%
#TAsk8
text = "Learning Python is amazing"
words=text.split()
print(words)

# %%
#Task9
squared= [x**2  for x in range(1,11)] 
print(squared)

# %%
#Task10
cumle = input("Cumleni daxil edin:")
cumle2 = list(cumle.split())
print(cumle2)
print(len(cumle2))
cumle3=str(cumle2)
print(cumle3.upper())

# %%
#Lists 1
fruits = ["apple", "banana", "cherry", "orange"]
print(f"{fruits[0]} {fruits[-1]} {len(fruits[1])}")

# %%
#Task2
nums = [33, 44, 55]
nums2 = nums[::-1]
numbers=nums + nums2
print(numbers)

# %%
#Task3
scores = [45, 12, 99, 67, 67, 23]
scores.sort(reverse=True)
print("Azalan: " , scores)
scores.sort(reverse=False)
print("Artan: ",scores)

# %%
#Task4
arr = [23, 45, 67, 34, 67]
print("En boyuk eded: ",max(arr),
      "\nEn kicik eded: ",min(arr),
       "\nCem: ",sum(arr))

# %%
#Task5
students = [
["Ali", 20, "Baku"],
["Leyla", 22, "Ganja"],
["Rauf", 19, "Sumqayit"]]
print(students[0][2],students[2][1])

# %%
#Task6
print("Yaslarin cemi: ",students[0][1]+students[1][1]+students[2][1])

# %%
#Task7
animals = ["dog", "cat", "bird", "fish"]
animals.insert(2,"bear")
print(animals)

# %%
#Task8
tic_tac_toe = [
['X', 'O', 'O'],
['O', 'X', 'O'],
['X', 'O', ' ']
]
tic_tac_toe[2][2]='X'
print(tic_tac_toe)

# %%
summ=0
students = [
["Ali", 20, "Baku"],
["Leyla", 22, "Ganja"],
["Rauf", 19, "Sumqayit"]]
for x in students:
   summ = summ + x[1]
print(summ)

# %%
np.array([[1,2,3],[5,6,7]])

# %%
plt.hist(np.random.rand(100000),density=True,bins=100,histtype="step",color="blue",label="rand")
plt.hist(np.random.randn(100000),density=True,bins=100,histtype="step",color="red",label="randn")
plt.axis([-2.5,2.5,0,1.1])
plt.legend(loc="upper left")
plt.title("Random distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
a = np.array([14, 23, 32, 41])
b = np.array([5,  4,  3,  2])
print("a + b  =", a + b)
print("a - b  =", a - b)
print("a * b  =", a * b)
print("a / b  =", a / b)
print("a // b  =", a // b)
print("a % b  =", a % b)
print("a ** b =", a ** b)

# %%
h = np.arange(5).reshape(1, 1, 5)
h+[10,20,30,40,50]

# %%
m=np.array([10,20,30,40,50])
m<[15,20,30,40,10]

# %%
#Soft Task1
numbers = [3, 5, 7, 2, 8]
print("Cem:",sum(numbers))

# %%
#Task2
fruits = ["alma", "armud", "banan"]
for x in fruits:
    print(x)

# %%
#Task3
colors = ["qırmızı", "yaşıl", "mavi", "sarı"]
print(len(colors))
