# %%
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1

# %%
#1
n=0
while n < 10:
    print(n)
    n+=1

# %%
#2
n=10
while n > 0:
    print(n)
    n-=1

# %%
n = int(input("Faktorial ededini daxil edin:"))
fakt = 0
m=1
while fakt <= n:
  fakt *= m
  m+=1
  if fakt == n:
      print(m)

# %%
n=1
while n<20:
    if n%2==0:
        print(n)
   
    n+=1

# %%
l=[]
while x:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print(sum(l))

# %%
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1
else:
    print("Sade ededdir")

# %%
#14
import random

m=random.randint(1,100)
print(m)
n = int(input("Ededi daxil edin:"))
while n!=m:
   n = int(input("Ededi daxil edin:"))
else:
  print(n,"eded dogrudur")

# %%
#4
l=[]
while True:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print("Cem:",sum(l))
       break

# %%
n = int(input("Faktorial ededini daxil edin:"))
fakt = 1
m=1
while fakt <= n:
  fakt *= m
  if fakt == n:
      print(m)
      break
  m+=1

# %%
ad="Gulay"
kod=1234
username=str(input("Adinizi daxil edin:"))
password=int(input("Kodunuzu daxil edin:"))
cehd=0
while cehd < 3:
    username = input("Adinizi daxil edin: ")
    password = int(input("Kodunuzu daxil edin: "))
    
 if username=="Gulay" and password==1234:
    print("Welcome")
    break
 else:
    cehd+=1
 if cehd>= 3:
    print("Account blocked")

# %%
n=0

while n< 50:
  if n % 7==0 :
      m=str(n)

      if len(m)==1:
          pass
      elif m[0]!= m[1]:
          print(n)
  n+=1

# %%
#12
n = int(input("Ededi daxil edin:"))
m=2
while m<n:
    if n%m==0:
        print(n,"Sade eded deyil")
        break
    m+=1

# %%
n = int(input("Ededi daxil edin:"))
l=""
m=0
while m<n:
    m=n%10
    l+=str(m)
print(l)

# %%
#1
n=0
while n < 10:
    print(n)
    n+=1

# %%
#2
n=10
while n > 0:
    print(n)
    n-=1

# %%
#3
n=1
while n<20:
    if n%2==0:
        print(n)
   
    n+=1

# %%
#4
l=[]
while True:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print("Cem:",sum(l))
       break

# %%
#5
n=1
summ=0
while n < 100:
    summ+=n
    n+=1

print(summ)

# %%
#6

while True:
   passw=input("Kodu daxil edin:") 
   if passw=="python":
       print("Kodunuz dogrudur")
       break

# %%
#7
n = int(input("Ededi daxil edin:"))
m=1
fakt=1
while m<=n:
   fakt*=m
   m+=1
print(n,"ededinin faktoriali:",fakt)

# %%
#9
i=1
while i<50:
    if i%3==0 and i%5==0:
        print(i)
    i+=1

# %%
#10
l=[]
while True:
    n = int(input("Ededi daxil edin:"))
    l.append(n)
    if n<0:
        print(max(l))
        break

# %%
#11
n=10
a=0
b=1

count=0
while count<n:
    c=a+b
    print(c)
    a=b
    b=c
    count+=1

# %%
#12
n = int(input("Ededi daxil edin:"))
m=2
while m<n:
    if n%m==0:
        print(n,"Sade eded deyil")
        break
    m+=1

# %%
n = int(input("Ededi daxil edin:"))
l=""
m=0
while m<n:
    m=n%10
    l+=str(m)
print(l)

# %%
def func(n):
    m=1
    while m <= n:
     print(m,end='')
     m+=1


func(5)

# %%
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
    m+=1
    if n%m==0:
      print("Sade eded deyil")
      
      break
else:
      print("Sade ededdir")

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n = int(input("Faktorial ededini daxil edin:"))
fakt = 0
m=1
while fakt <= n:
  fakt *= m
  m+=1
  if fakt == n:
      print(m)

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n=1
while n<20:
    if n%2==0:
        print(n)
   
    n+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
l=[]
while x:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print(sum(l))

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n = int(input("Ededi daxil edin:"))
m=2

while m<n:
   
    if n%m==0:
      print("Sade eded deyil")
      break

    m+=1
else:
    print("Sade ededdir")

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
#4
l=[]
while True:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print("Cem:",sum(l))
       break

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n = int(input("Faktorial ededini daxil edin:"))
fakt = 1
m=1
while fakt <= n:
  fakt *= m
  if fakt == n:
      print(m)
      break
  m+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
ad="Gulay"
kod=1234
username=str(input("Adinizi daxil edin:"))
password=int(input("Kodunuzu daxil edin:"))
cehd=0
while cehd < 3:
    username = input("Adinizi daxil edin: ")
    password = int(input("Kodunuzu daxil edin: "))
    
 if username=="Gulay" and password==1234:
    print("Welcome")
    break
 else:
    cehd+=1
 if cehd>= 3:
    print("Account blocked")

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
n=0

while n< 50:
  if n % 7==0 :
      m=str(n)

      if len(m)==1:
          pass
      elif m[0]!= m[1]:
          print(n)
  n+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
#12
n = int(input("Ededi daxil edin:"))
m=2
while m<n:
    if n%m==0:
        print(n,"Sade eded deyil")
        break
    m+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
#3
n=1
while n<20:
    if n%2==0:
        print(n)
   
    n+=1

# %%
# Bu kod if-istifadəsi ilə şərt yoxlayır
#4
l=[]
while True:
   x = int(input("Ededi daxil edin:"))
   l.append(x)
   if x ==0:
       print("Cem:",sum(l))
       break
